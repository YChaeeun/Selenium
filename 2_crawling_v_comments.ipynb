# %%
from selenium import webdriver as wd

import time, urllib
from tqdm import tqdm_notebook

# %%
# 접속
# 크림히어로즈 '모모와 루루가 결국 한판 붙었어요'
driver = wd.Chrome('./tools/chromedriver.exe')

param = urllib.parse.quote('xNp7Bw3sN3c')
site ='https://www.youtube.com/watch?v='+param

driver.get(site)

# %%
# 스크롤 내려서 댓글 전체 가져오기

for _ in tqdm_notebook(range(10000)):
    driver.execute_script('window.scrollBy(0,500)')
    
# 댓글 더보기 누르기 #replies #more .onclick()
# 추후 추가하기
# Out:
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))

# %%
# int 자료형으로 저장하기 위해 4,300 => 4300 으로 바꾸는 작업

def del_comma(string) :
    if ',' in string :
        string = string.replace(',', '')
    return string

# %%
# 영상 제목 .title yt-formatted-string
# 댓글 작성자 #author-text span
# 댓글 내용 #content-text a
# 댓글 좋아요 수 #vote-count-middle

# %%
title = driver.find_element_by_css_selector('.title yt-formatted-string')
title = title.text
title
# Out:
# '모모와 루루가 결국 한판 붙었어요'

# %%
comment_writer = driver.find_element_by_css_selector('#author-text span')
comment_writer.text
# Out:
# 'Ganon01 Ryan Outsen'

# %%
comments = driver.find_element_by_css_selector('#content-text')
comments.text
# Out:
# 'Garfield vs raccoon who will win!'

# %%
c_likes = driver.find_element_by_css_selector('#vote-count-middle')
c_likes = int(c_likes.text)
c_likes
# Out:
# 454

# %%
content = driver.find_elements_by_css_selector('#comments #contents #comment')
len(content)
# Out:
# 1117

# %%
v_comments = list()
for values in tqdm_notebook(content) :
    comment_writer = values.find_element_by_css_selector('#author-text span')
    comments = values.find_element_by_css_selector('#content-text')
    c_likes = values.find_element_by_css_selector('#vote-count-middle')
    
    # 좋아요 값이 있다면 int 형으로 바꾸고, 없다면 0으로 처리
    if c_likes.text :
        c_likes = int(c_likes.text)
    else :
        c_likes = 0
        
    dic1 = {
        'v_title' : title,
        'comment_writer' : comment_writer.text,
        'comments' : comments.text,
        'c_likes' : c_likes
    }
    v_comments.append(dic1)
v_comments
# Out:
# HBox(children=(IntProgress(value=0, max=1117), HTML(value='')))
# [{'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Ganon01 Ryan Outsen',
#   'comments': 'Garfield vs raccoon who will win!',
#   'c_likes': 454},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '도노 강',
#   'comments': '5:11 츄츄 모해 ㅠㅠㅠㅠ 귀여먀 ㅠㅠㅠㅠㅠㅠ❤️',
#   'c_likes': 863},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Hoshi Sasayaku',
#   'comments': '5:12 💞 Chuchu day dreaming, not having a care in the world, is just too cute! 😆',
#   'c_likes': 322},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Shaina Majumder',
#   'comments': 'Momo and Lulu fight to see whose Stamina is better.',
#   'c_likes': 141},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Hannah Dunn',
#   'comments': '5:11 \nChuchu : if i stay quiet and not moving, no one will see me (camouflage) hehe\nButler : chuchu what are u doing? Lets go~\nChuchu : ......',
#   'c_likes': 280},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Error Kitty',
#   'comments': 'I like how Momo was the first one to punch lulu but then got up and left and tricked Ms. Butler thinking that Lulu punched him instead XD',
#   'c_likes': 122},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Ayush Shukla',
#   'comments': 'Momo: Pat my butttttt 😂😂',
#   'c_likes': 167},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Safira febrianti',
#   'comments': '5:12 chuchu looks cute!?',
#   'c_likes': 108},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Crystal McKinney',
#   'comments': "Mom's fur says Spring is here",
#   'c_likes': 29},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '연듀 연듀',
#   'comments': '5:21초에 아기냥이 ASMR~~',
#   'c_likes': 143},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'NowYouSimi',
#   'comments': 'Momo is the charismatic Chairman with a bit of an old soul and a playful side that comes out on the little things like with toys and his favorite seat. His personality is so endearing ☺️',
#   'c_likes': 24},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '모니모니',
#   'comments': '모모 회장님은 루루를 정말 좋아하는 것 같아요-!\n항상 루루를 봐주는 기분ㅠㅠㅠㅠ엉엉\n우리 모모 하고 싶은거 다해💜',
#   'c_likes': 56},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Bae Sinrin',
#   'comments': 'I dont know why but there must be one scene in some creamheroes videos that could use as a meme😅',
#   'c_likes': 57},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Chau Nguyen',
#   'comments': 'Two thing....\nOne... a retro typewriter key board... big thumbs up 👍\nTwo... LuLu demanded attention and MoMo not liking it..👊👊👊',
#   'c_likes': 29},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Iris Reeve',
#   'comments': "5:11 ChuChu's in another dimension. She's saving the world, can someone just clap at her? she is an awesome kitty doing a pretty important job 😂💞.",
#   'c_likes': 68},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Itchyfinger',
#   'comments': 'The rivalry continues . hahahaha',
#   'c_likes': 22},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Prabha damu',
#   'comments': 'Good mrng ms.butler family.....dd,tt,chuchu,coco,lala,momo,lulu😘😘😘lulu boy always rocking love u lulu😘😘😘lulu fan from தமிழ்நாடு',
#   'c_likes': 11},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Ddarke11',
#   'comments': "Momo! You're supposed to set a good example for the kids!",
#   'c_likes': 22},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Rachel Rubin',
#   'comments': "Wow! LuLu isn't afraid of MOMO's STAMINA!!! I love my Chairman.❤",
#   'c_likes': 25},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'longifee fy',
#   'comments': 'I just love that we could see that Momo also likes being pet not only pang pang. 💖',
#   'c_likes': 32},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Fabiola Álvarez',
#   'comments': 'Your cats are very funny 😍',
#   'c_likes': 15},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '뉸뉴냔냐 〰[ 오늘 밤 주인공은 ]',
#   'comments': '2:11 : 루루와 모모는 아주 친한 칭구 !! ❤️\n\n2:35 : 모모는 착하게 루루에게 구르밍을 해줍니다\n\n : 둘이 눈이 맞은 후 ..\n\n : 모모의 선공격 ❗️\n\n : 당황한 루루 😫\n\n : 땡글한게 귀여운 루루 뒷통수\n\n : 모모눈빛 , 거의 암살직전\n\n : 편안한 루루 & 삐진 모모\n\n : 티티 “ 에휴 한심한 것들 ”\n\n[ 보 너 스 ]  : 츄츄의 애교폭팔 ❤️❤️',
#   'c_likes': 160},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Yiqing Ichigo',
#   'comments': "chuchu play dead when eating time,haha! please,don't worry about gain weight,our princess <3",
#   'c_likes': 33},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Anything',
#   'comments': 'That keyboard looks like old typewriter but cool',
#   'c_likes': 22},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '가은GAEUN',
#   'comments': '모모랑 루루는 사실은 친하면서 부정하는게 아닐까.. "나 쟤랑 안 친하다고오!" 그러면서 같이 붙어다니는 아가들..',
#   'c_likes': 232},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Shashank Jha',
#   'comments': '2:43\nMomo punching lulu. Best scene, i paused and  laughed for a minute,😂😂 then resumed and saw the rest',
#   'c_likes': 14},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'MIYUT미윳',
#   'comments': '다리가 넘짧잖아ㅠㅠㅠㅠㅠㅠㅠ긔엽댕아ㅠㅠㅠㅠ 이쁜건 너네들이 짱이야,,,✨',
#   'c_likes': 133},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Foxtail May',
#   'comments': "MoMo's golden fur...how much is the price? :)",
#   'c_likes': 12},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Maria Elena Agdinaoay',
#   'comments': 'Dont fight LULu & Momo. Love only❤',
#   'c_likes': 9},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '크림향고양이',
#   'comments': '5:11 츄츄 진짜 독보적인 고양이야ㅋㅋㅋㅋㅋㅋ주변의 상황은 마치 다른 세상인 것같이 드러누워서 허공을 바라보는게 너무ㅋㅋㅋㅋ숨소리까지 독특해ㅋㅋㅋㅋㅋ',
#   'c_likes': 94},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '모두의 냥이',
#   'comments': '4:42 이와중에 루루 밥먹을라고 뛰어가는거봐😭😭😭쫄래쫄래😚',
#   'c_likes': 82},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'LG Hakubi',
#   'comments': "Yay a MoMo video!\n\nI've never seen the focus on MoMo.\n\nHe and Lulu act so much like siblings, with MoMo being a teenager and Lulu being a child xD",
#   'c_likes': 11},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Ayush Shukla',
#   'comments': 'Oh my Lulu Lulu 😍😍',
#   'c_likes': 43},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '앙대',
#   'comments': '2:29 왜 갑자기 싸우는지 난 아직도 모르것다 ㅋㅋㅋ',
#   'c_likes': 127},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '윤이버셜YUNIVERSAL',
#   'comments': '모모야 루루야ㅋㅋㅋ 사이좋게 지내길 바라',
#   'c_likes': 8},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Anurul Hiraq',
#   'comments': 'Chuchu made an outstanding poses throughout the video. Love chuchu',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Ana & Devi',
#   'comments': 'Hi mrs butler ! Can u make a special video about breeds of all ur cats ?',
#   'c_likes': 13},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Tatum Anderson',
#   'comments': 'ChuChu.exe has stopped working.',
#   'c_likes': 17},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Nindi Tharya',
#   'comments': 'Luluuuuu🤣😭🔥❤️❤️❤️',
#   'c_likes': 11},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Cecilia Lin',
#   'comments': 'It’s her kids, they all have a personality lol~',
#   'c_likes': 11},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Raidenze',
#   'comments': "Just establishing dominance I guess, and Lulu's the clear winner.",
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Yitachi Hokage',
#   'comments': '1:42 HOW HANDSOME COCO ISS!!!',
#   'c_likes': 19},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Setyawati Ahmad',
#   'comments': '😄 😄 😄 😄 😄 The fighting that makes people happy..\nLulu MOMO. 😘😘😍😘',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '하긴 물어보면 뭐하냥..',
#   'comments': '회장님과 루랑이는 서로 투닥거리면서 또 잘 지내는 형제??\n빗대 말하면 돈많은 회장님에게 친구같은 비서랄까\n라고 생각됨ㅋㅋㅋ',
#   'c_likes': 90},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Bon Bon Girl',
#   'comments': 'Exactly What My Cats Do!',
#   'c_likes': 6},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '이중인격진끼',
#   'comments': '루랑이는 계속 몸만 길어지고 다리는 안 길어지는....',
#   'c_likes': 205},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Hyunji Kim',
#   'comments': '1:09 두들기게\n10:24 내다팔게',
#   'c_likes': 42},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '쑴',
#   'comments': '회장님 요즘 라라한테 쫓기고 맞고 루루한테 뻇기고 ㅠㅠㅠ힘내요 회장님의 삶이란..',
#   'c_likes': 43},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Dinner parties for lonely hearts *',
#   'comments': 'Chuchu can see the universe and the great beyond, that’s why she stares',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '해늘수녕',
#   'comments': '회장님 쮸굴쭈굴 물러나면서도 눈이 이글이글 불타올라서 억울해서 한대는 치고 가야겠다...!하는데 모모만 세상 다 잃은거 같고 루루는 원하는거 다 이루고 이긴거 같고ㅋㅋㅋ큐ㅠㅠㅠㅠ투닥즈 최고야 귀여워,,',
#   'c_likes': 50},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'machiell Official',
#   'comments': 'Luluu...',
#   'c_likes': 12},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '운옐완댜님',
#   'comments': '모모랑 루루는 싸우는게 아니라 사실...\n\n\n\n\n\n티티의 냥냥펀치수업 실습중이었다고 한다...🥊',
#   'c_likes': 62},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '빛이 당신을태울 것입니다',
#   'comments': '1:31 TT on FIRE 🔥🔥',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '가영',
#   'comments': '9:45 츄츄ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 루루 꼬랑지에서 치이고 있어',
#   'c_likes': 52},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '루루',
#   'comments': '모모형 자꾸 짧다고 놀리면 혼쭐나요!!!',
#   'c_likes': 29},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Nadhira A Wulandari',
#   'comments': 'Now we know where TT got that skill',
#   'c_likes': 6},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Faria _FF 035',
#   'comments': 'Apa cuman gue orang Indonesia  yg ada disini ...?😁',
#   'c_likes': 14},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '꿀지',
#   'comments': '3:37에  티티가 모모를 질투하고 있다... 이글이글..부들부들! ...',
#   'c_likes': 11},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '최윤정',
#   'comments': '5:11 츄츄 건전지 빠졌어요',
#   'c_likes': 59},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'banned 2000',
#   'comments': "5:14. LOL.\nCHU CHU:-I don't care.",
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'APARNA RAO',
#   'comments': 'Lulu, stop being a cute rowdy!',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '기린',
#   'comments': '7:15 사건의 시작',
#   'c_likes': 42},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'マグメル',
#   'comments': 'チュチュがフリーズしてるの可愛いw',
#   'c_likes': 6},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Riza Perwira Malang City',
#   'comments': 'LULU & DIREKTUR MOMO..\n 😸😹😹😻😽😼😼',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'M Szabo',
#   'comments': 'Lulu is sooooooo cute:)))❤️',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'YUHWA S',
#   'comments': '2:23 \n-(..좀 좁은데..)\n-야, 옆으로 좀 가.\n-야, 옆으로 좀 가아\n-ㅇ.ㅇ\n-야, 옆으로 좀 가.\n-ㅇ .ㅇ)\n-옆으로 좀 가라고!!!!!!!!!',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '나능리냥곤듀님',
#   'comments': '긔염 뽀짝 루루띄8ㅅ8 오늘도 힐링하고 갑니다리',
#   'c_likes': 10},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '루랑이초꼬초꼬빔',
#   'comments': '용맹한(?) 루루찡\n애교쟁이 섹시도발 집사껌딱지 모모찡\n이글이글 질투심 불타오르는 우아한 티티찡\n사차원 츄츄찡',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Luna. A. Goldstien',
#   'comments': '8:15저거 저거 타자기 뭐에요 저 타자기 어디꺼에요!!!',
#   'c_likes': 18},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Tiwiee Wiee',
#   'comments': 'Lulu...i love u so muchhhhhhh...',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'A The best',
#   'comments': '모모 지난번에 루루한테 그루밍 받더니 확실히 떡졌내요;; 대중탕 갈 날이 멀지 않아보여요....🤣',
#   'c_likes': 8},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Iris Reeve',
#   'comments': "2:34 I've never seen MoMo licking someone else but CoCo. 2:42 Even so, LuLu didn't like it lolololol.",
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '차팀장Mr Cha',
#   'comments': '모모는 루루를 못이김\n루루가 쪼꼬쪼꼬빔 발짜하면\n다쥬금 귀여워 쥬금\n근데 회장님 털이 탈모수준으로 빠지는데\nㅋㅋㅋ',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '실로폰',
#   'comments': '울 츄츄는 어떻게 숨소리까지 사랑스러울까♥♥\n커헠 심쿵이야♥',
#   'c_likes': 9},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '쿠림스',
#   'comments': 'Momo is so cute I love it',
#   'c_likes': 6},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '하이나',
#   'comments': '모모는 털로번식하나?\n왜이리 털을 뿜뿜하지?',
#   'c_likes': 9},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'jul jeo',
#   'comments': '나는 보았찌 루루모모가 사실은 아가앞에선 겁쟁이콤비였다는 거슬ㅋㅋㅋㅋㅋㅋㅋ 버즈가 부릅니다 겁쟁이랍니다~~',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '냐옹',
#   'comments': '현실 형과 아우 같네요ㅋㅋ친한것 같다가도 투닥투닥ㅋㅋ형이라고 그래도 싫지만 매번 양보하는 형아 모모ㅋㅋ형님이 하는건 무조건 탐나고 질투나는 아우 루랑이ㅋㅋㅋ\n근데 진짜 루랑이는 츄츄한테만 져주는 건가요~?ㅋㅋㅋ',
#   'c_likes': 15},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Neko Neko',
#   'comments': "Momo's love\nMr.Mouse>>>>>>>TT>Mommy>Lulu",
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'mahmudha hime',
#   'comments': 'Lulu tak terkalahkan 😅😅😍😍😍😍😍😍😚😚',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김희원',
#   'comments': '집사님 7분 52초 쯤에 사용한 키보드?같은거 어디꺼에요?',
#   'c_likes': 14},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Andrea Bergagna',
#   'comments': 'Momo precioso!! esa carita que pone cuando le quita Lulu el ratoncito!!! Es muy dulce!!💓',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '루루귀여워',
#   'comments': '크림히어로즈 영상을 보면서 항상 느끼는거지만 냥이들 넘 귀엽고 행복해보여서 좋아요~\n힐링하고 갑니다♥♥',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Tata Si boneka',
#   'comments': 'Chuchu!!!',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '풍요로운나',
#   'comments': '2:10 부터 자리신경전 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ루루 너가 쫌만 옆으로갔어도 회장님이 열받진않지ㅋㅋㅋㅋ',
#   'c_likes': 14},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '桜田美桜',
#   'comments': 'ChuChuLove♡',
#   'c_likes': 8},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김똥꾸',
#   'comments': '2:12 루루,,,너 진짜 빅헤드,,,,,,,,,,,,,,,,',
#   'c_likes': 15},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Mylv_ Filza',
#   'comments': 'Love lulu ❤',
#   'c_likes': 6},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '11269INDIAN',
#   'comments': 'Lulu fight,Lulu fight!!!!!!!!',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '빈체로',
#   'comments': '보면 디디 티티 코코 모모가 루람쥐랑 라먐이한테 일부러 져주고 그러네요ㅎㅎㅎ 우애가 좋네요~~♡♡',
#   'c_likes': 6},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ABHIJIT DUTTA',
#   'comments': 'At my local area and cat injured. I noticed it 2 days ago . Injury in  waist so nt able to walk . As a romet place of india  animal doctor not available. How can i do for his treatment.',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'R Guleria',
#   'comments': 'One side is Lala and Lulu : the looters and then there is Chuch the dreaming Princess 😘😍😍💟',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'sekar andhini',
#   'comments': 'DD, TT, Lulu, Momo, Coco, Lala, Chuchu is so Cute....!!!!',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Debarshi Majumdar',
#   'comments': 'At 3:00-3:02..the killer looks of momo..omg...I laughed out so hard...haha the relationship between lulu n momo is just like siblings. .:)..they fight..they love ..feel jealous of each other..so nice bonding..love all creamheroes',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Fakhri Soni',
#   'comments': 'Indonesia',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Chad Schmaltz',
#   'comments': 'Momo: "Listen, youngster. Don\'t make me lay the smackdown on you!!"\nLulu: "You don\'t scare me, gramps. I\'m Lulu, the fierce feral kitten!!"',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Zuahar Latifah',
#   'comments': 'Lulu lucu bgt deh',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Arie Canary',
#   'comments': '2:45 tragedi😂😂😂😂😂\nMomo : im attack you LULU\npaw paw paw paw attack\nLulu : !?!?!?😕😕😕😕 what MOMO attack me with PAW😕😕😐🐈\nMama : hihihi😂😂😂😂',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'FLYING HIGH',
#   'comments': '루루가 일방적으로 두둘겨 맞았을뿐 ㅠ  집사님의 저 핑크색 신문물은 뭔가요?',
#   'c_likes': 16},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김소연',
#   'comments': '7:13 오... 솔로몬이신가요?',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '환시란',
#   'comments': '8:13초쯤에 노트복갇은거는 태블릿을 연결해서 사용하는 걸까요?',
#   'c_likes': 9},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Kalpana Bhoir',
#   'comments': 'LULU & MOMO😘😘😘😘😘so sweet .....love to watch them together again & again.🐈😻😻🙀👊👊👊👊\n😺😺😹😹💕💕💕💕 \nLove from INDIA💋❤',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Mylv_ Filza',
#   'comments': 'Soo cute 😭😭😭',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Kale Monster',
#   'comments': 'TT is my favorite tsundere',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Ava',
#   'comments': 'Oh Ms. Butler, thank you for doing a "sort of" Momo episode! We love, love him and "his" voice. He\'s so precious. Can you do a Dr. Coco video one day please? And a Lala 💗 video too? Thank you for making my night. Love from California, USA',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '다은',
#   'comments': '모루모루는 황상에 조합(?)',
#   'c_likes': 9},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'MI LAU',
#   'comments': 'Oh no, be friendly Mr. MOMO and LULU 🤓🤓',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 's.',
#   'comments': "Chairman Momo! Don't fight. <3 you.",
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '겸둥휘',
#   'comments': '5:31 루랑이 인형이닷~!!',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '최고냥이',
#   'comments': '모모랑 루루 싸우기 2탄 !!!!ㅋㅋㅋㅋㅋ\n싸우지 마 ♡♡♡♡♡♡♡♡♡♡',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '♡Julia TV♡',
#   'comments': '솜망치로 때리는거 저만 귀엽나요???',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Davina putri',
#   'comments': 'Apa cuma gua yg orng indo?\nHai lulu i am from indonesia🇮🇩',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Estrella Hermosillo',
#   'comments': '5:11 Same chuchu same',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Dedi Edwin Dedi',
#   'comments': 'Lulu apa kabar....love you',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '이쏘',
#   'comments': '5:10 아..츄츄 숨소리.. 쌔애애액삐이이익..♥ 언제들어도 넘모조아 ㅠㅠ♥♥',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'HJ Kim',
#   'comments': '집사님 불타지 않으셨나요? 티티가 아주 그냥 태워버릴 기세로 뒤에서 쳐다보고있는데ㅋㅋㅋㅋㅋㅋ 귀여워ㅋㅋㅋㅋ 옆에와서 부비적거리지ㅠㅠㅠㅠ',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '크림냥냥이들짜냥해',
#   'comments': '여러분여러분!!\n5:31 에 루루인형이!!!\n헐 서있는 포즈라 진짜 루루같고 완전 귀여미해여 ㅠㅠ\n혹시 굿즈내시..면 디디인형도',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Chanju Kim',
#   'comments': 'Tough love.',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'sekar andhini',
#   'comments': 'Cute Cat and Smart Cat',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '난폭한 젤리',
#   'comments': '루루는 자존심이 쎈 고양인거 같아욤...',
#   'c_likes': 9},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '향악',
#   'comments': '앜 루랑이 앞발은 언제나 기여버♡',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '포시{ᄋᄉᄋ}',
#   'comments': '빨리 왔댜 루루가 모모 털 빗겨줄때\n따라가는 것 너무 귀엽닼ㅋㅋㅋㅋ',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ateng mioblack',
#   'comments': 'Lulu kalah menang tetep lawan',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '바삭한몽쉘',
#   'comments': '모모랑 라라가 아니라구요?! 아... 그건 모모가 일방적으로 당하는사인가ㅋㅋ',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'teho Tyler',
#   'comments': '츄츄 : 아무생각이 없다 아무생각없기 때문이다...냥',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '운옐완댜님',
#   'comments': '이글 티티는 오늘도 냥냥펀치로 때릴냥이를 찾으러갑니다 후후...\n\n\n\n\n\n그것 마저 귀여운 티티',
#   'c_likes': 8},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'kiLLRustoLeYum',
#   'comments': "MOMO-What, you don't like my affection. Alright how about my double right cross. Bam-Bam. LULU-No, No i don't like those either.",
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김지예',
#   'comments': '모모 하악하는거 첨봤어...루루야',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Andra Amalia',
#   'comments': 'Helooo luluuu💛💛',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Sonal Jaiswal',
#   'comments': 'My lulu momo luv u',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '아이유가최고야',
#   'comments': '흐어ㅠㅠ 오늘도 집사님은 귀엽고 모모 회장님은 땡그란 눈을 우옥ᆞ!!! 글구 루루는 또 크핳ㅠㅠ♥ 싸우지마ㅠㅠ',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '// //',
#   'comments': '7:04 모모 루루한테 하악질한거야...???ㅋㅋㅋㅋ',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'eka Syirfa',
#   'comments': "Did anyone known how's DD weights? I'm so curious",
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'NORI U',
#   'comments': 'ㅋㅋㅋ 루루 멍때리다가 당함 ㅋㅋ 퍽퍽',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '최프리',
#   'comments': '7:56소리 넘후좋당/~',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Shaina Majumder',
#   'comments': '1:37 Lol 3:17 Feels sad',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김똥글',
#   'comments': '티티 빼꼼하면서 질투의시선 왜케기엽냥ㅋㅋㅋ',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'レナ',
#   'comments': '1:35 티티..😂😂😂😂😂',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Hanifah Zahrah',
#   'comments': 'indonesia',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '코시 바 툴르 Khosibatul Almanshur',
#   'comments': '그들은 모두 룰루와 모모에게 매우 친숙합니다.',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '긴예원',
#   'comments': '인트로에 츄츄ㅋㄱㅋㅋㄱㄱ 귀여워 ㅠ ㅠ',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '냥아치후추',
#   'comments': '2:45 아니 냥님들 제발 싸우는 이유만이라도 알려주세요 제발 이유만이라도 아니 그루밍 잘해주다가 왜 면상 싸닥숑을 때리는지 진짜 이해가 1도 안가서 그런데 제발 이유만 알려줘요 싸우지말라고는 안할게요',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'nazenith1',
#   'comments': '불타오르는 티티 눈동자',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '크림냥냥이들짜냥해',
#   'comments': '근뎅 아무리 봐도\n모모가:이새끼 많이컸네?조금 싸워줄까?\n루루:이이이이!이이이이!내가 더 커오!\n모모:?????\n너무 귀여워요 ㅠㅠ \n얘드라 싸우지망 누굴 응원할지 모르겠다구!!!',
#   'c_likes': 15},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '안수민',
#   'comments': '애들 털빗기 영상 오랜만에 보고싶어유ㅠㅠㅠ 모모털빗을때 너무조아..',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '녠엘',
#   'comments': '아아 ㅜㅜ 루루 진짜 왜케 귀여워 ㅜㅜ 귀여운 이유가.. 다리가 짧고 , 야옹거리는 소리가 귀엽고 , 뛸때 뒤뚱 거리는거 귀엽구 , 표정 자체가 귀여움 ㅜㅜ',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '빙수',
#   'comments': '모모❤️루루의 사랑(?)은  계속됩니다ㅋㅋㅋㅋ',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Emilia M.',
#   'comments': 'So cute.♡',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '뚜찡',
#   'comments': '아이구ㅎ루루랑 모모랑 싸우다니...생각도못했어욤 그래두 아가들이여서 귀여워요ㅎ',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'aloha nn',
#   'comments': '08:02 아니 무엇인가요 이 신문물은...!!!!',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '뿌꾸빵뿡',
#   'comments': '집사님!!! ㅠㅠ 고양이슬리퍼 너무 잘받앗습니다ㅠㅠㅠ너무 귀여워요ㅠㅠㅠ 이대로 여름용 슬리퍼도 만들어주실수잇으신가요오...❤️',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '코시 바 툴르 Khosibatul Almanshur',
#   'comments': '나는 그들의 아주 귀여운 얼굴, 크림 영웅을위한 인사를보기 위해 설 수 없습니다.',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '담료ღ[담요분들]',
#   'comments': '2:44ㅋㅋㅋㅋㅋ',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Cherry🍒',
#   'comments': '더보기에 써주시는 글들.. 글만 읽어도 항상 음성지원 ㅎㅎㅎㅎㅎㅎㅎ헿',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '원쥬',
#   'comments': '2:23~2:29 흔한 사장님과 비서의 비밀적인 사생활(?)',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Funny Meow Meow',
#   'comments': 'When cats trained for MMA',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '봇별',
#   'comments': '집사님 이번 에코백 굿즈 배송해주실 때 사은품으로 모모 회장님의 저 아름다운 황금빛 털을 같이 주시는 게 어떨까요..ㅎㅎ',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '기린',
#   'comments': '9:59 아프게따',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '혜빔Hyebin',
#   'comments': '루랑이두ㅠㅠ회장님두ㅠㅠ둘다 깜찍하구 사랑스럽당ㅠㅠ\n크림히어로즈 앞으로도 화이팅!!!!! ٩ˊᗜˋ*',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Manh Attan',
#   'comments': 'Lulu  awn',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Setu singh Rajput',
#   'comments': 'Chu chu 🤣🤣',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '루루 한마리주세요',
#   'comments': '회장님과 루랑이의 한판 승부',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '정다혜',
#   'comments': '귀여워ㅠㅠㅠㅠㅠㅠ루루야ㅏㅏㅏㅏㅏㅠㅜㅠㅠㅠㅠㅠ흑흑 죽겠다 넘 귀여워서',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Lupita Bravo',
#   'comments': 'Momo❤❤❤❤❤',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ᄄ ᄄ',
#   'comments': '몸모 겁나 잘 패ㅋㅋㅋ ㄲㅋㅋㅋㅋㄱ',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'APPLE Lab',
#   'comments': '7:04 회장님 하악해쏘ㅠㅠㅠㅠㅠㅠ❤️',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '유진YUJIN ˇ',
#   'comments': '2:07 은근의 밀치기 싸움',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '꼬북이바보',
#   'comments': '오모....다리 왤케 귀엽나규♥️♥️♥️♥️♥️♥️♥️♥️♥️♥️알람 넌 나한테 죽을 준비하거라....♥️♥️\n2:45 냥냥펀치의 시작🐾🐾',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '; ᄋ',
#   'comments': '츄츄 눈 똥그랗게 뜨고 누워있는거 너무 귀여웤ㅋㅋㅋ5:11',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'RichieLarpa',
#   'comments': 'Anyone from Czech Republic or Poland?',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Yess DD',
#   'comments': '7:05 회장님 쥐돌이가 얼마나 좋았으면 하악질ㅋㅋㅋㅋㅎ 근데 루루줬ㅅ지ㅠㅠㅠㅠ',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '미니',
#   'comments': '♡♡♡♡♡♡♡',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Elias Almeida',
#   'comments': "Se que no leeras esto :'v pero Te veo y me pregunto de que trabajas? :v aveces te ves exausta",
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '햄찌',
#   'comments': '아니 요즘 모모... 티티한테맞구 라라한테 맞고... 루루한테도..😂 냥이들 서열 영상 다시찍어주셔야 겠는데요???🤭',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '?맥주',
#   'comments': '아니 5분쯤에 츄츄 영혼이가 없어보여요..',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Vaishnavi Zade',
#   'comments': 'Momo and lulu have fighted over that scratcher before too😂😂so cute😍💎',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Lightning Samos',
#   'comments': 'Chuchu es taaaan 😍❤😻😺',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'pirera pirera',
#   'comments': "My brown cat has been stolen.. It's a little bit remember me about him when I watch Momo.",
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '한가한 초원 chowon',
#   'comments': '2:44 모루모루 싸움시작',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Yuchi Mashima',
#   'comments': 'Lulu : i want dat toy too~\nMomo : HIIISSSSS',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Kami Sama',
#   'comments': 'Momo and Lulu have a love hate relationship because of Chuchu and TT lol',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '눈꽃냥이',
#   'comments': '결국 붙었구나..\n옜날부터 싸우더니\n그래도 귀엽......♡',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '담엕',
#   'comments': '모루모루는 사랑 ...',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'lo g',
#   'comments': 'Wonderful video!\nChuchu version div@!\nChuchuuuuuuuu!  Love youuuuuu!   ❤❤❤',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Happy Day',
#   'comments': 'LMBO Momo was grooming nicely and I guess Lulu didn’t like it. But Lulu, he’s just showing affection like you do!',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Sarah Fatima',
#   'comments': '😂😂😂the last dialogue ...go and sell ...is epic😂😂😂😂',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Sarah Fatima',
#   'comments': 'U know.   when I watch DD n TT n the rest  they Remind  me of the Truman show ..who is bored of this ...and want to explore  more  worlds...😂😂just my thought',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'guzide ulgen',
#   'comments': 'OMG,BIG KISSES from ANTALYA TURKEY',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '자세히보기',
#   'comments': '모모야 다음엔 루루에게 이기자!',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'dommyshan',
#   'comments': "Sadly, Momo's combed ball of fur has more Stamina! than me.",
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '`아메',
#   'comments': '5:11 \n츄츄:주근척 하고이써여 (๑ↀᆺↀ๑)',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'b수',
#   'comments': '아니 오프닝 티티 뭔가욬ㅋㅋㅋㅋㅋ눈에서 불이...엄마의 주변을 향한 질툰가요....ㅋㅋㅋㅋㅋ',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'shella allehs',
#   'comments': 'How to say "don\'t fight" to them? haha',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Aulidya Syifa Adzani',
#   'comments': 'I like you cat vidio',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'MICHAEL FRIEL',
#   'comments': 'LULU is savage. Like a jungle tiger, speed, strength, stamina, her paw strikes are equivalent to a Mike Tyson punch. A perfected specimen, chiseled by nature, she rules the wild. A savage beast indeed.',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Tyrone Tabornal',
#   'comments': 'Roses are Red\nViolets are Blue\n\nI just in Loved \nwith CreamHeroes \n\n\nSo Do you? ❤️',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Rahadian Yusuf',
#   'comments': 'Imagine your cats are waiting for you to come home is imposi..\n\n\n\n\n\nwait, whattt?',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '미토mitto',
#   'comments': '오늘 꿈에 루루가 나왔어요.... 살짝 뒹굴듯이 앉아서 그루밍을 했는데... 땅콩이 있는걸 보고 꿈인걸 알아챘어요....',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Sarz Quiñones',
#   'comments': 'Maybe its because lulu is not used to being groomed by momo 🤣',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Ellie Park',
#   'comments': "I'm entranced by that detachable keyboard....",
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Eugene Cooper Jr',
#   'comments': "LuLu, even with short legs,doesn't back down. 😎🙏✌",
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Sarina Omar',
#   'comments': "Why you don't  care about the tt",
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '박수빈',
#   'comments': '귀여운모모,,맨날 뺏겨ㅠㅠㅠㅋㅋㅋㅋㅋㅋㅋ',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Herring',
#   'comments': '오늘은 모모시리즈!\n"Et Ham 계속 해보게~"',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Nath Paris',
#   'comments': '@9:59 MOMO DOESNT WANT TO SHARE ANYMORE LOL 😂😂😂',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Gabbin Tine',
#   'comments': 'Omg 0:03 seconds in and I’m dying Hahahaha',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'sasha Ruidias',
#   'comments': 'Minute 2:44 fight cats Momo vs lulu',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Jesus lover of my soul. Awesome God.',
#   'comments': 'Last video and this video has no english subtitles at all. Love these cream heroes videos lately. Love all of the 7 cats ms butler has.! Mono and lulu needs to play nice and get along. I wish i could meet all 7 sweetheart cats that ms butler has. To cute. It was so very sweet that mono gave ms butler kisses.',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '8schopra',
#   'comments': 'All This is so hilarious 😍😍💚👏',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'GRGNNafiis',
#   'comments': 'This day spesial for momo',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '블랙핑크',
#   'comments': '귀여미들♥알람뜨자마자 왔어요♥',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Findra Shinn',
#   'comments': 'Lulu do bad thing? Yes, but everything he do is forgiven by his cuteness 😂😂😂',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Lady Aya',
#   'comments': "Lulu wants to play with Momo but Momo wasn't in the mood bcs earlier Lulu punched him when he groomed Lulu 😂",
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Iris Reeve',
#   'comments': '5:20 The duo of the glutton but cute and little kittens, 5:25 The trio of A W E S O M E kittens and 5:29 the duo "we\'re just lovely" kittens 👌💖.',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'PugGirl Hills',
#   'comments': 'Haha they’re always fighting... Lulu wins again!',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '[SM]Sans Minorie',
#   'comments': 'Lulu vs momo who will win?',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Gabriela Chang Ping-Nions',
#   'comments': '2:42 Lulu : what are you doing ? \nMomo : stop moving and let me groom you damn it !!',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'sasayaki',
#   'comments': 'Lulu was the mellow one this time 😁',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '꿍쓰네하우스',
#   'comments': '싸우는것도 귀여워ㅠㅠㅠㅠ❤️',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김가은',
#   'comments': '집사님이 쓰시는 저 타자?자판?기 탐난다..',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Mahmuda Sarker',
#   'comments': "Momo and Lulu are definitely Feisty Brothers! 😾🤜😾\nAnd at 2:41, it's so funny how Momo just grooms Lulu and goes straight to hitting him lol like why be nice and then suddenly hit him haha. Then at    1:37 and 3:37 TT be staring out jealousy all the way through 😲💔😐 haha\n\nP.S. ChuChu is so weird and cute lying down like that at  haha",
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'rosee ditaa',
#   'comments': 'Lucu banget jadi pengen punya peliharaan kucing❤',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '페티petty집사',
#   'comments': '다정하게 그루밍해주다가 갑자기 왜 때려ㅋㅋ 졸귀♡',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김정호',
#   'comments': 'Round 2',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'MOCHAMAD AJI',
#   'comments': 'Only love watching Lulu. The rests are no way.',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Yolanda Guzman',
#   'comments': 'y love coco and lulu :3 :D',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '샤밀샤쿰',
#   'comments': '루루가 모모에게 복수를 앜 하는거 같아오 모모가 때려서 근데 루루가 모모의 아래인가?못때리네...',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'serene 00',
#   'comments': '.... Momo punched Lulu first 😂',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '루루지훈',
#   'comments': '싸우면 때찌한다!!! ㅠㅠ',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'FROYO NION',
#   'comments': 'lulu is very cute ♡♡♡',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Nelly Vásquez Serrano',
#   'comments': 'Bellos!!  ❤️❤️❤️❤️❤️❤️',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'JBJ_9289 ASIAN-DRAMA&K-POP LOVER',
#   'comments': 'Momo & Lulu don’t fight..',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '루랑이는루르렁',
#   'comments': '츄츄는 인형인듯...😍',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'wanna-one워너블',
#   'comments': '엊그제 봤을때가구독자  216만이엇던것 같은데 며칠만에 덕자분들이 3만명이 올라갔네요 ㅎㅎ모모 츄츄 루루 코코 라라 티티 디디 보고 힐링하구갑니다아--->_<',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '짠쨩',
#   'comments': '01:40 ???누군가요 이건',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김유정',
#   'comments': '으아유ㅠㅠ오늘두 너무 귀여워유ㅠ\n저희 집에는 고양이 한마리있는뎅♥',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Samruddhi',
#   'comments': 'Lulu 🐈',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '이효정',
#   'comments': '세상에 ㅠㅠㅠ 츄츄 인형인줄 ㅠㅠㅠㅠㅠㅠ',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '송이',
#   'comments': '오구 똥고양이들이~ 한바탕 싸웠어요~?',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '수히오& 꽁뀨퐁!',
#   'comments': '루루 불쌍해ㅠㅠㅠㅠ\n모모 불쌍해ㅠㅠㅠㅠㅠ',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ta sa',
#   'comments': '집사님 모모는 집사님을 더 사랑할거에요.\n루루 욕심꾸러기 근데 너무 귀여워~~',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Cintya',
#   'comments': 'Momo 💛',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '빨간 머리 앤 엘리스',
#   'comments': '싸우는것도 귀여웡💓💓💓',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '이예슬',
#   'comments': '옛날에도 누가 결국 한판 붙은 거 잇지 않았나요ㅋㅋ 루루랑 티티였나?',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '내 이름은 코박사우주의 수호 과학자이죠',
#   'comments': '회장님하고 박사님이 진짜 츤데레에 정석인게 집사님이 가면 스리슬적 와서 잘가 이러고 오면 쓰윽 와서 왔어?이러고 만져주면 저리가는데 또 안만져주면 와서 나 궁디 쳐죠!만져줘!이러고 증말 모코모코 사랑한다😍',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'FIFAFI FARAH',
#   'comments': 'lulu makan tempat kali makanya momo sebel😊😂😂😁😁',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '안녕나는츄츄',
#   'comments': '티팈ㅋㅋㅋㅋㅋㅋㅋ 이글이글ㅋㅋㅋㅋㅋㅋㅋㅋ',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Lyra Kim',
#   'comments': '저 타자기 뭔지 물어봐도 되나요 집사님?! 탐이난다...',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '캐럿세븐틴',
#   'comments': '엔딩 샷에 컷쥬 오마이갓~🎶 이런 노랴 나와야 될듯한..',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '호구와구유튜브',
#   'comments': '오늘도 잘 보고 있어요~',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Stickers On A Laptop',
#   'comments': 'Uh I want that keyboard',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Alawiyah Deajeng',
#   'comments': '2:07 Molu (Momo Lulu) my couple 😅😅',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'angga lukman',
#   'comments': 'Colab sama kucing petani 😊',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'arieyana yazmin',
#   'comments': 'I LOVE you LULU !!',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'A K',
#   'comments': '이세상 귀여움 너네들이 짱먹어라ㅠㅠ',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'FerriaBerry',
#   'comments': 'OMG! They are so cute even when they fight! xD Oh btw.. may I ask, where did you get your ipad keyboard? I love it! Do you have a link? ❤️',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Tata Sunarta',
#   'comments': 'Come to Indonesia 🇮🇩 😀',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김여진',
#   'comments': '세상에 집사닙 타자기 저거 뭔지 아시는분 있나요😭😭',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '최현빈',
#   'comments': '모모회장님이겨라!',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '아이코닉지연',
#   'comments': '루랑이랑 모모회장님이랑 비슷하게 생긴건 기분탓이겠죠?',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '봃앯엟롷엟봻',
#   'comments': '0:01????????',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'seo funcrew',
#   'comments': '짧은 다리로 선방했나?!!!! 선이플 후감산',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'itaaa yooo',
#   'comments': 'Indonesia mana like nya',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '담료ღ[담요분들]',
#   'comments': '???:원래 애들은 싸우면서 크는거여',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Uci Hwaiting',
#   'comments': 'Ooh Lulu imuuuuuut skaleeeeeee😍😍😍😍😍😍',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '루랑이는루르렁',
#   'comments': '루랑이 이 욕심쟁이ㅋㅋㅋㅋㅋㅋㅋ모모가하는건 다 좋아보이나봐',
#   'c_likes': 5},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Sarina Omar',
#   'comments': 'Chuchu so funny',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'kyle jung',
#   'comments': 'ㅎㅎ 루루는 깡패구나?ㅋ',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '츄츄예요',
#   'comments': '와중에 타자기 취저ㅠㅠㅠ',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Aurelliamanda Puteri',
#   'comments': 'Kasihan momo😂',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Caticorn Gurl',
#   'comments': '5:12 Chuchu looks kinda traumatized...',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ياسر مشهور',
#   'comments': 'اول',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '이하',
#   'comments': '모몸야ㅠㅜㅜㅜ오랜만에 많이보니깐 좋앗ㅎㅅㅎ',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '루루해적단항해사',
#   'comments': '5:11 10:28 (피식ㅋ)',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Wassana Sanmongkol',
#   'comments': 'ละไปนอนเบียดกันทำไมคะลูกกกก',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '배윤설',
#   'comments': '2:42 그룽그룸~~ 퍽퍽ㅋㅋ',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'siuping au',
#   'comments': 'LuLu & Mo Mo 😻💞so cute 💞😙',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Arcade',
#   'comments': 'Team MOMO!',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'You know bts?',
#   'comments': 'Lulu💜',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Cinthia Hermawan',
#   'comments': 'Lulu 😂😂😂😂🤣🤣🤣🤣',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '라온초코',
#   'comments': '꼬맹이들 싸우면 나쁜 어린이야 맴매!♥ 그와중에 루루 표정보소 귀여워용^^',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Yeonju Oh',
#   'comments': '모모ㅋㅋ 요즘 티티누나한테 부비고 다니더니 냥냥펀치 기술 제대로 전수받았어😎',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '65 1',
#   'comments': '6:30 큐티뽀작',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '짜낭버디',
#   'comments': '싸우는것도 너무 귀여워 사랑해',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Rizki Puspita',
#   'comments': 'TT😘',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '으어어어',
#   'comments': '루랑아~^^루루♡♡♡♡♡♡♡❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '만렙데먼',
#   'comments': '아앙!!! 너무 귀여웡!!',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '학봉',
#   'comments': '루루 나의최에케',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '빛랑',
#   'comments': '솜방망이 펀치!!!!',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'vaopy cat الأحمري',
#   'comments': 'ووواااووو',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '하쿠나',
#   'comments': '숏다리 루루VS롱다리 모모',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '사과파이',
#   'comments': '싸워도 귀엽다!',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '똥꾸멍',
#   'comments': '싸우지망ㅜ 귀요미들💕',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '물먹어',
#   'comments': '루루동네북이냥ㅜㅜ',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '뚠뚠 뚠뚠',
#   'comments': '모모회장님 하악 7:03',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '정승연',
#   'comments': '싸우지마 ㅎㅎㅎㅎ 친하게 지내장♥',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '「뿌이」진교_:D',
#   'comments': '아구아구 기여웅',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '갓쨩 • 30년 전 .',
#   'comments': '수정:모모가 참다참다 폭팔했어요',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '일사륙',
#   'comments': '모모가 쥐돌이 갖고노는데 루루가 다가오길래 또 카샤카샤처럼 야무지게 물고 으르릉거리면서 뒷걸음질 치려고 하는 줄 알았더니 쥐돌이 장난감에 붙은 털ㅋㅋㅋㅋ 핥으려고ㅋㅋㄱㅋㅋㅋ 진짜 털이란 털은 다 핥는구나...',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '맨너굴',
#   'comments': '1:35 🔥_🔥',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '이방인',
#   'comments': '3:37 티티가 무서운 눈으로 모모를 째려보고있다.. 곧 어마무시한 냥냥펀치가 모모의 머리를 강타할지도 몰라!',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Kunku Kun',
#   'comments': '3:02 하이라이트..',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '슝슝',
#   'comments': '회장님자리 그냥물러나기엔 너무 속상해서  냥냥뻔치날리고  물러나주기',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '백사랑',
#   'comments': '루루 그루밍 해주다 뜬금없이^^;;;;; 회장님, 여기서 이렇시면 안됩니다ㅋㅋㅋㅋㅋ',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '강밍밍',
#   'comments': '집사님의 머릿색과 회장님 모모의 털 색 중 누가 더 골드 스럽나야.?.?.?',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '뽀레',
#   'comments': '루루!이겨라!!',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '박관록',
#   'comments': '4:57 아옹~',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'yj ki',
#   'comments': '모모 ㅡ 이보게 나도 한번 만져주시게',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '고양이키우고싶다',
#   'comments': '10:37 사진 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#   'c_likes': 2},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '작은순례자',
#   'comments': '헐 모모 하악질까지 했어 ㅋㅋㅋㅋㅋ\n가끔 티티랑 모모보면 늙어서 아랫놈들한테 서열 밀린 사자들 같아서 불쌍해 보임 ㅠㅠ',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '카톡카톡꿀잼',
#   'comments': '이놈이 또간식을 약탈하는구만!\n아잇 회장님 간식도 챙겨준다니까요!\n2개정도는 챙겨줘야지!',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '쿠로스코네',
#   'comments': '5:11 츄츄 모야ㅠㅠ',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '강명순',
#   'comments': '여기 외국인들 엄청많네..고양이들은 역시 언제봐도 귀엽다니깐 ㅎ',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'hg Bae',
#   'comments': '모모는 라라하고 티티한테 맨날 맞던데 그리고 디디 귀엽다 빵줘라',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ii ch',
#   'comments': 'ㅠㅠㅜ최애냥 디디랑 모모 중에서 모모가 많이  나오는 영상이 없어 슬펏는데.. 오늘 영상 너무 보배로우ㅓ요.. ㅠㅠㅠㅠㅠㅠㅠ 모모야 궁디팡팡길만 걷자 ㅠㅠㅠㅠㅠㅠ',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'luckhopelove',
#   'comments': '모모가 은근히 여리네요><.... 아기도 무서워하고, 루루한테 자리랑 장난감 뺏기고, 라라한테 쫒기고ㅠㅠ 울 회장님 요즘 가오가 안 살아 ㅠㅠ',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ati아티',
#   'comments': '모루모루는 같이있으면 귀여운뎅...❤(쿨럭) 계속 싸우고있어요~ㅜㅜ 루루는 숏다리인데 이기고(바준건가?모모가)모모는 롱다리인데 지고 아니 둘이있을때 시청자들은 편하게~보고있으면 모모가 롱다리로 때려서 웃음이나와요~~모루모루가 싸우는건 초코와 모카가 싸우는거 같아요...모루모루 싸우지마세요~귀옆고 잘생긴 얼굴이 찌그러져요.....근데 오늘 츄츄의 엉뚱한거를 봤어요...아 심장아 나대지마...ㅜㅜ',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김진희',
#   'comments': '2:42 모모:뭘봐\n2:43 모모:뭘보냐고 또보면 때린다\n2:44 모모:보지 말랬지!!!!\n2:45 루루:내가 뭔잘못을 했는데!!때리지 마!!',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '가을단풍',
#   'comments': '회장님이 겉만 저러시지 사실 루루한테 항상 양보하고 챙겨주는  츤데레 같아요 (겉은 차갑 속은 따뜻한 츤데레 모모회장님 사랑해요♡)',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '미세고양이',
# ...
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '자유부인',
#   'comments': '모모 회장님...자꾸 볼때마다 요다가 생각나요...☆',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '소이',
#   'comments': '오늘도 냥이들 너무 귀엽고 ㅠ \n집사님 타자소리너무 좋아요 ㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '빼꼬미에요',
#   'comments': '역시ㅋㅋㅋ엄청 용감한 루루💜맘씨 좋은 모모회장님이 봐주시는거겠죵?ㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '녹차티팩',
#   'comments': '7:49 부터 예사롭지 않은 키보드 소리... 타자 빠르시다(제 기준)',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '토끼절편',
#   'comments': '08:30 루루인형이라도 노려보는 모모',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ღ츄빔인뎅?',
#   'comments': '02:44 부터  보면 ㅋ  진짜 팬다 ㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '유리미',
#   'comments': '5:15 진짜 인형 아닙니까..',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '작은순례자',
#   'comments': '5:11 츄츄는 인형 변신 스킬을 사용하였다.',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '강호철',
#   'comments': '회장님과 루꺽정이 어쩌다가ㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김민수',
#   'comments': '티티앞에서는 순해지는 작은아이들..',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Hwan Lin',
#   'comments': '모모와 루루 사이좋게 지내는 모습이 아름다운데 ㅠㅠ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '캌',
#   'comments': 'TT인트로 ㄱㄴㅌㅋㅋ 눈에 불을키고있네요ㅜㅜ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Sonal Jaiswal',
#   'comments': 'I like cream heroes',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '마크는애옹애옹',
#   'comments': '저도 라라 코 만지구 시퍼요...먀..',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '지혜jihyeLee[트와이스팬 원스 지효 팬]',
#   'comments': '엔딩 거의 회장님이. 루루한테 협박하는줄..ㄷㄷ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '정예린',
#   'comments': '와 털이 진짜 많이 빠지는구나....',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'kill Naz',
#   'comments': '싸움났다해서 구경왔습니다~',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': "채빔'",
#   'comments': '애들아 싸우묜 혼나요오 왤케 기엽♡',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ha Ja',
#   'comments': '아니 뭔 타자기가...?',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '항상 배고픈 지으ᄂ',
#   'comments': '왜 알림이 2시간 뒤에 뜰까요...? 😠',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'lydia20513',
#   'comments': '모모가 이기는 구나... ㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '크림냥냥',
#   'comments': 'ㅋㅋ 사이좋게 지내야지~!ㅋㅋ 루루,모모!!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '웰시코기',
#   'comments': '5:31 루루 새로운 인형인건가요 ㅋㅋㅋㅋ 귀엽다',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '지나가던길냥이',
#   'comments': '5:11  츄츄 뇌ㅡㅡㅡㅡ절',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '딸기처럼',
#   'comments': '모모랑 루루 너무 잘어울려요~❤️❤️',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'heenew KIRA',
#   'comments': '인트로에 티티뭐야 ㅋㅋㅋㅋ 눈에서불이 ㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '안수상',
#   'comments': '루루 저넘 지가 귀여운거 알고잇어',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '썬데이해피',
#   'comments': '그 털 살게요!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '제로니모',
#   'comments': '모모 : (뜬금) 구텐 퍽!\n루루 : 퍽퍽! 이건 하극상이애오!!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '몽실몽실몽쉬르',
#   'comments': '아구 모모 장난감가지고 놀아요~',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김기현',
#   'comments': '모모: 이런 버르장머리없는 녀석!! \n퍽!퍽!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '아ᄋ아ᅡ악!!아ᅡ악ᄀ!!!',
#   'comments': '모모 넘 귀여워 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅜ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '도리 도리',
#   'comments': '뜬금 없지만 집사님 컴퓨터 기종 뭐뭐 가지고 계시나요?',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '강지은',
#   'comments': '애구  싸우는 것도\n귀엽지만  싸우진 마라 \n귀염둥이들♡♡♡',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김성준',
#   'comments': '마지막 킬링포인트 ㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Minimin H',
#   'comments': '그 털 제가 사죠🤔',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '강지연',
#   'comments': '루루멘토모모',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '안윤정',
#   'comments': '갈 수록 힘이 좋아지는 루루와 회장님 포스의 모모 참 귀여워요^^',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '키루바스',
#   'comments': '츄츄는  안때리는 센스봐라',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '이정민',
#   'comments': 'ㅠㅠ 모모야루루야싸우지마',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ㅤㅤ시아zzz6',
#   'comments': '진정하세요 루랑이랑 회장님!!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '사랑해루랑아',
#   'comments': '마지막\n모모:이익!\n루루:으악!!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '허구여',
#   'comments': '오.... 모모 무서워.... 회장님 포스....',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '방탄바라기',
#   'comments': '너무 사랑스럽다! ㅎㅎ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '_애으앵',
#   'comments': '루루 진짜 고양이계 인싸.....',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '우리 함께하는 지금,화양연화',
#   'comments': '모루모루ㅠㅠㅠ 아구 예뻐',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '몽실몽실몽쉬르',
#   'comments': '티티ㅋㅋㅋ 매 화면에서 이글이글거려ㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'SK검정덕후',
#   'comments': '그 와중에 이글이글 티티ㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '『둥실이분들』서현둥이',
#   'comments': '오오 꽤 일찍 왔어여ㅕ!ㅎㅎ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '유티나',
#   'comments': '18분전인데조회수가 ㄷㄷ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'poo poo Lee',
#   'comments': '츄츄 순간 고장난 인형 같았어요~~ 귀여워~',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '물검은',
#   'comments': '모모는 봐주지 않지..',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '박민영',
#   'comments': '앞 티팈ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 눈에 불ㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '정정인정',
#   'comments': '루루야! 싸랑해요~💗💕💓💞💖',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '내얼굴리자몽',
#   'comments': '하여튼 못말려~~~~~',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '방탄은사랑이다',
#   'comments': '루댕이 넘 기여버여 ㅜ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '눈 감으신서강희',
#   'comments': '싸움구경하러 왔다가 인트로 츄츄보고 터졌넼ㅋㅋㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '박병길',
#   'comments': '티티 눈치주는거봐',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '캡짱',
#   'comments': '회장님 사랑해요 ㅠㅜ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '햄구르미',
#   'comments': '크흐흐 인트로에 츄츄 너무 귀엽네요ㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '[아티아스]다민',
#   'comments': '루루가  움찌했는데  마자또 ㅠㅠ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ByunJu Lee',
#   'comments': '그루밍해주다가 왜때료ㅋㅋ큐ㅠㅠㅠㅠㅠ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '잡덕쓰',
#   'comments': '진짜 귀여워ㅜㅜ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '123익명',
#   'comments': '모루모루 ㅠㅠㅠ 싸우지마 ㅜ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Bonnie보니',
#   'comments': '츄츄 ㅋㅋㅋㅋ 왜저랰ㅋㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '민쵸[코난 사랑해]',
#   'comments': '싸우지 마시게나',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ヒウン',
#   'comments': '회장님 하악질 했닷ㅠㅠㅠㅠㅜㅠ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Shin Ye Eun',
#   'comments': '루루 팬이에요 \n루루 진짜 귀여웡 \n😘😘😘',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '강유진',
#   'comments': '8:41 루루인형, 언제 나오나요?',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Aimee Moon',
#   'comments': '완죤 양아치자너',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Summer Design',
#   'comments': '사랑이 가득한 냥냥펀치 😍😍😍',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Rising Sun flag equal Nazin',
#   'comments': '그래서 얼만가요?',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '우비랑구름이랑',
#   'comments': '아치(냥아치)루랑~',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '아ᄋ아ᅡ악!!아ᅡ악ᄀ!!!',
#   'comments': '7:04 루루를 향한 모모의 하악질',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '유티나',
#   'comments': 'ㅜㅜㅡㅜㅜㅠㅜㅠ넘귀여워모모모모모',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Korea Happy_boy',
#   'comments': '싸우지마 애들아 ㅠㅠ 싸우는것도 귀엽',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Zali Ro',
#   'comments': '싸우지마라 냥냥',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '뷉붸부벱ᄇ',
#   'comments': '다들 루루랑 한판씩 싸우네욬ㅋ',
#   'c_likes': 11},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '고독이',
#   'comments': '기여운 냥이들 ㅠ',
#   'c_likes': 4},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'yee췍췍',
#   'comments': '어흑',
#   'c_likes': 1},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '긓튜브artistgh',
#   'comments': '8:15 키보드 정보좀...ㅜㅜ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '지뾰',
#   'comments': '끄흫ㅎㅎ모모귀여워아아아아ㅠ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '최현호',
#   'comments': '항상 힐링하고 갑니다.',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '민윤기천재짱짱맹뿡뿡',
#   'comments': '구르밍해주다가 왜갑자기때렼ㅋㅋㅋㅋㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '뇸니-',
#   'comments': '본격적으로 싸우는 장면 : 2:44',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '래여',
#   'comments': '내다 팔게ㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '마스크',
#   'comments': '언제나 귀여우신 집사님 ㅜㅜ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '로제',
#   'comments': '넘나 역동적인 막짤ㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '리후이',
#   'comments': '밧아랏! 모모펀치~~!!!!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'kuri Yo',
#   'comments': '2분41초에 왜 때리는거얔ㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '루랑이루루 so cute!',
#   'comments': '싸움이고 뭐고 일단 넘 귀엽다ㅠㅠ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '자고싶다잠만',
#   'comments': '보기 힘든 모모 하악 7:03',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '멍블비',
#   'comments': '회장님 참아요 참아~',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '라ლ르',
#   'comments': '싸우지마ㅠㅠ 너무 카와이해♡♡',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '피넛츠',
#   'comments': '5:12 엌ㅋㅋ 뭐얔ㅋㅋㅋ 너무 귀여웤ㅋㅋㅋㅋ♡♡♡',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '은하수:D 누가 은하수 구독을 하였는가?',
#   'comments': '넘 귀여워ㅜㅡㄴ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '탱꾸구',
#   'comments': '티티 눈에 불난다아아아아!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ki ho Han',
#   'comments': '캬캬캬캬캬캬캬캬',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '디디티티루루',
#   'comments': '티티 눈에 불 나는거 너무 귀엽자나욬ㅋㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '공주왕자',
#   'comments': '둘이 합쳐서 모루',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Ash Kim',
#   'comments': '쥐돌이가 되고싶다,,,',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'futasupastah',
#   'comments': '헐~~ 싸우지마라  얘들아 ㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '3720김상혁',
#   'comments': '더 흥해라',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '황정림',
#   'comments': '루루야 왜 또 싸워ㅠㅠㅋㅋㅋㅋㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '므앵',
#   'comments': '10:31 하이라이트컷ㅋㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '後後',
#   'comments': '오프닝 티티 ㅋㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '장희형',
#   'comments': '둔둔이ㅎㅎ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '러버모코모코',
#   'comments': '간만에 모모 오래봐서 너모 행복~💕',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '브오tv',
#   'comments': '루랑아',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'ᄋᄇ',
#   'comments': '5:17 츄츄숨소리인가요?ㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '카요무비',
#   'comments': '냥냥펀치🐱🐱🐱',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '정재열 개좋아',
#   'comments': '다들 츄츄얘기밖에 안햌 ㅋㅋㅋㅋㅋ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '윤젤{vip빅뱅}',
#   'comments': '오 루루에오',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '무말랭',
#   'comments': '츄츄 숨소리 삐익삐익 ㅜㅜ 귀여워 ㅜㅜㅜ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '양진영',
#   'comments': '싸우면   큰일나!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'y s',
#   'comments': '츄츄 귀여워 미치겟네',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '볼프',
#   'comments': '6:00 너무 귀여워 ㅠㅜㅠㅜㅠ모모',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '라임스무디',
#   'comments': '꺄악 오늘도 졸귀~크림히어로즈 사랑해여',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '운옐완댜님',
#   'comments': '회장님과 루랑이는 뭘해도 커엽',
#   'c_likes': 7},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '[인형계]효루',
#   'comments': '와우 벌써 많이 오셨네요!\n역시 고양이들 핵귀여미',
#   'c_likes': 3},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '조승연',
#   'comments': '츄츄 인형이애오?',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '김규석',
#   'comments': '타자기?',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Ha Y',
#   'comments': '루루 깡패야...',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Cauchy Riemann',
#   'comments': '와 집사님 타자기ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '토멍이뽀로로',
#   'comments': '루량루량 귀여버',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '찡 삐',
#   'comments': '모모 동네북이야 ㅠㅜㅜㅠㅠㅠ',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Lisa Park',
#   'comments': '세상에 모루모루 조합좋네요♥',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'risyowo kawai',
#   'comments': '모모얗!!!!!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '이미순',
#   'comments': '너무 귀여웡 아가들',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': 'Serice Black',
#   'comments': '이쁜이들~',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '얼은케찹',
#   'comments': '서로 밟고 밟히는사이',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '*-**-*',
#   'comments': 'ㅋㅋㅋㅋㅋㅋ귀엽다',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '미소',
#   'comments': '왜 그래ㅠㅠ애기들',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '정상우',
#   'comments': '모모찡 사랑해~~~~♡',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '8672 Fitria',
#   'comments': '아이는 한번 😽',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '너블_nb',
#   'comments': '루랑이는용맹해여!!!!',
#   'c_likes': 0},
#  {'v_title': '모모와 루루가 결국 한판 붙었어요',
#   'comment_writer': '만성두통녀',
#   'comments': '츄츄 왜 고장났엌ㅋㅋㅋ',
#   'c_likes': 0},
#  ...]

# %%
import pymysql as sql
from sqlalchemy import create_engine

import pandas as pd
import pandas.io.sql as pSql

# %%
# DB에 적제하기
driver = 'mysql+pymysql://root:1234@localhost:3306/crawling'
engine = create_engine(driver, encoding='utf-8')

conn = engine.connect()

df = pd.DataFrame.from_dict(v_comments)
df.to_sql(name='v_comments', con=conn, if_exists='append', index=False)

# 만약 이모티콘 저장에 문제가 있다면
# 이모티콘 저장을 위해 DB 테이블 설정을 utf8mb4, utf8mb4_unicode_ci 로 변경

if conn:
    conn.close()
    print('엔진 정상 종료')
# Out:
# 엔진 정상 종료
